# %%
import numpy as np

# %%
def problem01a(number):
    digit_str = str(number)
    digit_list = [int(d) for d in digit_str]
    digits = np.array(digit_list)
    digits_shifted = np.append(digits[-1], digits[:-1])
    equal_inds = (digits == digits_shifted)
    output = np.sum(digits[equal_inds])
    print output

# %%
problem01a(1122)
# Out:
# 3

# %%
problem01a(1111)
# Out:
# 4

# %%
problem01a(1234)
# Out:
# 0

# %%
problem01a(91212129)
# Out:
# 9

# %%
problem01a(...)
# Out:
# 1102

# %%
def problem01b(number):
    digit_str = str(number)
    digit_list = [int(d) for d in digit_str]
    n_shift = len(digit_list)/2
    digits = np.array(digit_list)
    digits_shifted = np.append(digits[-n_shift:], digits[:-n_shift])
    equal_inds = (digits == digits_shifted)
    output = np.sum(digits[equal_inds])
    print output

# %%
problem01b(1212)
# Out:
# 6

# %%
problem01b(1221)
# Out:
# 0

# %%
problem01b(123425)
# Out:
# 4

# %%
problem01b(123123)
# Out:
# 12

# %%
problem01b(...)
# Out:
# 1076
